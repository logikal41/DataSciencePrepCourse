# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_json("https://api.census.gov/data/2015/acs5/variables.json")

# %%
df
# Out:
#                                                       variables
# AIANHH        {'label': 'FIPS AIANHH code', 'concept': 'Sele...
# AIHHTLI       {'label': 'American Indian Trust Land/Hawaiian...
# AITS          {'label': 'American Indian Tribal Subdivision ...
# AITSCE        {'label': 'American Indian Tribal Subdivision ...
# ANRC          {'label': 'Alaska Native Regional Corporation ...
# B00001_001E   {'label': 'Total', 'concept': 'B00001.  Unweig...
# B00001_001M   {'label': 'Margin Of Error For!!Total', 'conce...
# B00002_001E   {'label': 'Total', 'concept': 'B00002.  Unweig...
# B00002_001M   {'label': 'Margin Of Error For!!Total', 'conce...
# B01001A_001E  {'label': 'Total:', 'concept': 'B01001A.  SEX ...
# B01001A_001M  {'label': 'Margin Of Error For!!Total:', 'conc...
# B01001A_002E  {'label': 'Male:', 'concept': 'B01001A.  SEX B...
# B01001A_002M  {'label': 'Margin Of Error For!!Male:', 'conce...
# B01001A_003E  {'label': 'Male:!!Under 5 years', 'concept': '...
# ...
